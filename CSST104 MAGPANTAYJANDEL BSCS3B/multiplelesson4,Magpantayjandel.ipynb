# %% [markdown]
# ***MAGPANTAY, NINO JANDEL C***
#
# **BSCS-3B**
#
# **MR. BERNARDINO**

# %%
import pandas as pd #Data Manipulation
import numpy as np #Mathematical operation
import matplotlib.pyplot as plt #Data Vizualization
from sklearn.model_selection import train_test_split #Training Data/Data Modeling
from sklearn.linear_model import LinearRegression #Training Data/Data Modeling
from sklearn.metrics import mean_squared_error #Training Data/Data Modeling

# %%
df = pd.read_csv('Jandel.csv')
print(df)
# Out:
#      Hours_of_Study  Attendance_Percentage  Previous_Exam_Scores  \
# 0          4.370861              75.553988             63.085284
# 1          9.556429              86.257028             62.348940
# 2          7.587945              96.188375             95.312729
# 3          6.387926              91.966747             62.477310
# 4          2.404168              94.196834             63.597486
# ..              ...                    ...                   ...
# 995        1.824239              89.708655             93.264788
# 996        9.255822              98.698439             57.863660
# 997        2.231368              72.068740             65.489393
# 998        9.552136              71.711642             64.502277
# 999        5.014052              78.465612             93.570702
#
#      Extracurricular_Activities  Travel_Time_to_School     Grades
# 0                             0              24.325977  31.494329
# ...

# %%
x = df.drop('Hours_of_Study', axis=1)
y = df[['Grades']]

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)
df.head()
# Out:
#    Hours_of_Study  Attendance_Percentage  Previous_Exam_Scores  \
# 0        4.370861              75.553988             63.085284
# 1        9.556429              86.257028             62.348940
# 2        7.587945              96.188375             95.312729
# 3        6.387926              91.966747             62.477310
# 4        2.404168              94.196834             63.597486
#
#    Extracurricular_Activities  Travel_Time_to_School     Grades
# 0                           0              24.325977  31.494329
# 1                           0              50.132016  43.250150
# 2                           0              59.861895  30.155663
# 3                           1              11.501300  39.617522
# 4                           0              54.868293  33.175874

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict =model.predict(x_test)
print(x_test)
print (y_predict)
# Out:
#      Attendance_Percentage  Previous_Exam_Scores  Extracurricular_Activities  \
# 521              98.033081             56.721756                           1
# 737              75.838675             77.224117                           0
# 740              94.826137             68.284037                           0
# 660              88.017830             73.614090                           1
# 411              73.357589             57.027648                           1
# ..                     ...                   ...                         ...
# 408              87.560631             99.401798                           1
# 332              76.853642             80.189773                           1
# 208              78.208800             64.610912                           0
# 613              79.730013             87.045203                           1
# 78               76.547617             99.249483                           0
#
#      Travel_Time_to_School     Grades
# ...

# %%
mse = mean_squared_error(y_test,y_predict)
print(f"Mean Squarred Error: {mse}")
# Out:
# Mean Squarred Error: 5.206481974458678e-29

# %%
grades = [[70,91,95,60,58]]
predicted_grades = model.predict(grades)
print(f"Predicted: {predicted_grades[0]}")
# Out:
# Predicted: [58.]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
